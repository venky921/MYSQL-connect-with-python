# %%
# !pip install mysql-connector

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
venky=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Venky@2004",
    database="education_domain",
    auth_plugin="mysql_native_password",
    use_pure=True
)

mycursor=venky.cursor()

print(venky)

# %%
# !pip install --upgrade mysql-connector-python

# %%
mycursor.execute("select * from student_details")
output=mycursor.fetchall()
for x in output:
    print(x)
# Out:
# (1, 'Ravi', 'Kumar', 'Srinivas', datetime.date(2000, 1, 15), 'Male', 987654321, '1234-5678-9101', 'Plot No 23, Vijayanagar, Vijayawada, Andhra Pradesh', datetime.date(2019, 7, 1), 'BTech', 'Active', 'Yes', datetime.date(2023, 6, 15), 75000)
# (2, 'Sita', 'Reddy', 'Narayana', datetime.date(2001, 5, 20), 'Female', 9876543211, '1234-5678-9102', 'Street 5, Guntur, Andhra Pradesh', datetime.date(2020, 6, 1), 'BCA', 'Active', 'No', datetime.date(2023, 6, 1), 35000)
# (3, 'Anil', 'Naidu', 'Venkatesh', datetime.date(1999, 9, 30), 'Male', 9876543212, '1234-5678-9103', 'Madhurawada, Visakhapatnam, Andhra Pradesh', datetime.date(2018, 7, 15), 'BBA', 'Inactive', 'Yes', datetime.date(2022, 5, 10), 50000)
# (4, 'Priya', 'Iyer', 'Ganesh', datetime.date(2000, 11, 12), 'Female', 9876543213, '1234-5678-9104', 'Dwaraka Nagar, Kakinada, Andhra Pradesh', datetime.date(2019, 9, 5), 'MSc', 'Active', 'Yes', datetime.date(2024, 7, 12), 65000)
# ...

# %%
query="select * from student_details"
data=pd.read_sql(query,venky)

# %%
data.head()
# Out:
#    Student_id First_name Last_name Father_name         DOB  Gender  \
# 0           1       Ravi     Kumar    Srinivas  2000-01-15    Male
# 1           2       Sita     Reddy    Narayana  2001-05-20  Female
# 2           3       Anil     Naidu   Venkatesh  1999-09-30    Male
# 3           4      Priya      Iyer      Ganesh  2000-11-12  Female
# 4           5    Madhavi      Babu     Krishna  2002-02-14  Female
#
#    Phone_number   Aadhar_number  \
# 0  9.876543e+08  1234-5678-9101
# 1  9.876543e+09  1234-5678-9102
# 2  9.876543e+09  1234-5678-9103
# 3  9.876543e+09  1234-5678-9104
# 4  9.876543e+09  1234-5678-9105
#
#                                              Address Enrollment_date course  \
# 0  Plot No 23, Vijayanagar, Vijayawada, Andhra Pr...      2019-07-01  BTech
# 1                   Street 5, Guntur, Andhra Pradesh      2020-06-01    BCA
# 2         Madhurawada, Visakhapatnam, Andhra Pradesh      2018-07-15    BBA
# ...

# %%
data.shape
# Out:
# (3000, 15)

# %%
data.isna().sum()
# Out:
# Student_id              0
# First_name              0
# Last_name              17
# Father_name            29
# DOB                    12
# Gender                  0
# Phone_number           21
# Aadhar_number          25
# Address                26
# Enrollment_date         9
# course                 13
# Student_status          9
# Scholorship_status      5
# date_of_graduation     10
# Course_fee_per_year    10
# dtype: int64

# %%
data.columns
# Out:
# Index(['Student_id', 'First_name', 'Last_name', 'Father_name', 'DOB', 'Gender',
#        'Phone_number', 'Aadhar_number', 'Address', 'Enrollment_date', 'course',
#        'Student_status', 'Scholorship_status', 'date_of_graduation',
#        'Course_fee_per_year'],
#       dtype='object')

# %%
data.tail()
# Out:
#       Student_id First_name  Last_name Father_name         DOB  Gender  \
# 2995        2996      Kiran       Goud      Harish  2000-05-17    Male
# 2996        2997       Sree      Naidu      Raghav  1999-07-21  Female
# 2997        2998  Siddharth  Chowdhary     Bhaskar  1999-10-19    Male
# 2998        2999       Vani      Nayak       Vijay  1999-11-08  Female
# 2999        3000      Venky      Thota       Surya  2000-06-09    Male
#
#       Phone_number    Aadhar_number                        Address  \
# 2995  9.876546e+09  1234-5678-12095    Rajahmundry, Andhra Pradesh
# 2996  9.876546e+09             None  Visakhapatnam, Andhra Pradesh
# 2997  9.876546e+09  1234-5678-12097    Rajahmundry, Andhra Pradesh
# 2998  9.876546e+09  1234-5678-12098  Visakhapatnam, Andhra Pradesh
# 2999  9.876546e+09  1234-5678-12099                           None
#
#      Enrollment_date course Student_status Scholorship_status  \
# 2995      2021-09-11     BA         Active                 No
# ...

# %%
data.describe()
# Out:
#         Student_id  Phone_number  Course_fee_per_year
# count  3000.000000  2.979000e+03          2990.000000
# mean   1500.500000  9.873254e+09         53843.143813
# std     866.169729  1.637123e+08          9174.371814
# min       1.000000  9.876543e+08         35000.000000
# 25%     750.750000  9.876544e+09         46000.000000
# 50%    1500.500000  9.876545e+09         51000.000000
# 75%    2250.250000  9.876545e+09         65000.000000
# max    3000.000000  9.876546e+09         81000.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_id           3000 non-null   int64
#  1   First_name           3000 non-null   object
#  2   Last_name            2983 non-null   object
#  3   Father_name          2971 non-null   object
#  4   DOB                  2988 non-null   object
#  5   Gender               3000 non-null   object
#  6   Phone_number         2979 non-null   float64
#  7   Aadhar_number        2975 non-null   object
#  8   Address              2974 non-null   object
#  9   Enrollment_date      2991 non-null   object
#  10  course               2987 non-null   object
#  11  Student_status       2991 non-null   object
#  12  Scholorship_status   2995 non-null   object
#  13  date_of_graduation   2990 non-null   object
#  14  Course_fee_per_year  2990 non-null   float64
# ...

# %%
data.isna()
# Out:
#       Student_id  First_name  Last_name  Father_name    DOB  Gender  \
# 0          False       False      False        False  False   False
# 1          False       False      False        False  False   False
# 2          False       False      False        False  False   False
# 3          False       False      False        False  False   False
# 4          False       False      False        False  False   False
# ...          ...         ...        ...          ...    ...     ...
# 2995       False       False      False        False  False   False
# 2996       False       False      False        False  False   False
# 2997       False       False      False        False  False   False
# 2998       False       False      False        False  False   False
# 2999       False       False      False        False  False   False
#
#       Phone_number  Aadhar_number  Address  Enrollment_date  course  \
# 0            False          False    False            False   False
# ...

# %%
data['course'].value_counts()
# Out:
# course
# BBA      956
# BCom     956
# MSc      840
# BA        86
# BTech     66
# MTech     39
# BCA       24
# BSc       20
# Name: count, dtype: int64

# %%
#fill null values in cours feee 
mean_value=data['Course_fee_per_year'].mean()
print(mean_value)
# Out:
# 53843.14381270903

# %%
data['Course_fee_per_year'].fillna(mean_value, inplace=True)

# %%
data.head(48)
# Out:
#     Student_id First_name   Last_name    Father_name         DOB  Gender  \
# 0            1       Ravi       Kumar       Srinivas  2000-01-15    Male
# 1            2       Sita       Reddy       Narayana  2001-05-20  Female
# 2            3       Anil       Naidu      Venkatesh  1999-09-30    Male
# 3            4      Priya        Iyer         Ganesh  2000-11-12  Female
# 4            5    Madhavi        Babu        Krishna  2002-02-14  Female
# 5            6    Karthik      Vemuri    Ramachandra  1998-08-07    Male
# 6            7    Haritha    Chowdary          Pavan  2001-03-25  Female
# 7            8      Vamsi         Rao      Srinivasa  2000-12-18    Male
# 8            9      Kavya  Siddhartha          Vijay  1999-01-01  Female
# 9           10       Teja     Krishna         Ramana  2001-07-15    Male
# 10          11     Geetha       Nayak           None  2002-04-21  Female
# 11          12      Gopal     Chandra        Sitaram  1998-11-09    Male
# ...

# %%
#1) What is the distribution of courses in the dataset?
data['course'].value_counts()
sns.countplot(x='course',data=data)
# Out:
# <Axes: xlabel='course', ylabel='count'>

# %%
#2)How does the scholarship status vary across different courses?
sns.countplot(data,x="Scholorship_status",hue="course")
# Out:
# <Axes: xlabel='Scholorship_status', ylabel='count'>

# %%
#3)How does the course fee per year vary across different courses?
plt.figure(figsize=(18,9))
sns.boxplot(data=data,x='Course_fee_per_year',hue='course')
plt.show()

# %%
#4)What is the distribution of courses among students?
sns.countplot(data=data, y="course", order=data["course"].value_counts().index, palette="viridis")
# Out:
# <Axes: xlabel='count', ylabel='course'>

# %%
#5)What is the gender distribution of students?
sns.countplot(x='Gender',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>
